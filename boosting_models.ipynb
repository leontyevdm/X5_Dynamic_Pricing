# %%
from sklearn.metrics import r2_score, mean_squared_log_error, max_error

import pandas as pd
import numpy as np
import datetime
from time import perf_counter

from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.forecasting.arima import ARIMA, AutoARIMA

from tabulate import tabulate

import warnings
warnings.filterwarnings('ignore')

date_parser = lambda ts: datetime.strptime(ts, "%y-%m-%dT%H:%M:%SZ")
df = pd.read_csv('aviasales_data_t.csv')
df['requested_at'] = pd.to_datetime(df['requested_at'], format="%y-%m-%dT%H:%M:%SZ", errors="coerce")
df['departure_at'] = pd.to_datetime(df['departure_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['expires_at'] = pd.to_datetime(df['expires_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['price'] = pd.to_numeric(df["price"], errors="coerce")
df = df.dropna()
df = df.drop_duplicates(subset=['departure_at', 'expires_at', 'airline', 'flight_number', 'price'], keep='first')


def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


# Profile prediction func and test prediction quality
def ml_model_test(orgn : str, dest : str,
                  current_date : datetime.datetime, flight_date : datetime.datetime,
                  predictor_f, target_f):
    print(orgn, dest)

    tic = perf_counter()
    predictions = predictor_f(orgn, dest, current_date, flight_date)
    tac = perf_counter()
    elapsed_time = tac - tic
    
    targets = target_f(orgn, dest, current_date, flight_date)
    print(f"Elapsed time: {elapsed_time:0.4f} seconds")
    print(predictions[1], targets[1])
    
    r2 = r2_score(targets[1], predictions[1])
    msle = mean_squared_log_error(targets[1], predictions[1])
    max_err = max_error(targets[1], predictions[1])
    mape = mean_absolute_percentage_error(targets[1], predictions[1])
    
    print("R2:", r2)
    print("MSLE:", msle)
    print("Max error:", max_err)
    print("MAPE:", mape)
    
    return (str(predictor_f), orgn, dest, elapsed_time, r2, msle, max_err, mape)

# INSERT YOUR FUNCTION
def predict_queried_prices(orgn, dest, current_date, flight_date):
    days = []
    predictions = []
    delta = flight_date - current_date
    for i in range(delta.days + 1):
        days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
        predictions.append(predict_queried_prices_for(orgn, dest, current_date, flight_date, i))
    return days, predictions

def predict_queried_prices_for(orgn, dest, current_date, flight_date, n_days):
    
    orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date) 
                   & (df["requested_at"] >= df["departure_at"] - datetime.timedelta(days=n_days + 1))
                   & (df["requested_at"] <= df["departure_at"] - datetime.timedelta(days=n_days))] 
    
    orgn_dest_day_min = orgn_dest.resample('D', on='requested_at')['price'].min()
  
    orgn_dest_day_min = orgn_dest_day_min.fillna(orgn_dest_day_min.mean())  # not very smart
    
    y = orgn_dest_day_min
    y_train, y_test = temporal_train_test_split(y)
    
    forecaster = AutoARIMA()
    forecaster.fit(y_train)
    fh = ForecastingHorizon(y_test.index, is_relative=False)
    y_pred = forecaster.predict(fh)
    return round(y_pred[-1])

# INSERT YOUR FUNCTION
def show_real_prices(orgn, dest, current_date, flight_date, delta_days=7):
    
    orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date + datetime.timedelta(days=1))
                   & (df["departure_at"] >= flight_date)]
    
    days = []
    prices = []
    for i in range(delta_days + 1):
        orgn_dest_day = orgn_dest[(orgn_dest["requested_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
                           & (orgn_dest["requested_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
        if orgn_dest_day.empty:
            orgn_dest_day = orgn_dest[(orgn_dest["expires_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
                               & (orgn_dest["expires_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
        
        prices.append(round(orgn_dest_day["price"].min()))
        days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
        
    return days, prices



# JUST AN EXAMPLE

i = "MOW"
ml_test_results = []
for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
    for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
        if i != j:
            ml_test_results.append(ml_model_test(i, j, datetime.datetime(2021,4,20), datetime.datetime(2021,4,27),
                                             predict_queried_prices, show_real_prices))
ml_test_results.append(ml_model_test("MOW", "SGC", datetime.datetime(2021,4,20), datetime.datetime(2021,4,27),
                                             predict_queried_prices, show_real_prices))            
            
ml_test_df = pd.DataFrame(ml_test_results)
ml_test_df.columns = ['predictor_func', 'origin', 'destination', 'elapsed_time', 'r2_score', 'msle_score', 'max_error', 'mape']
print(tabulate(ml_test_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# MOW LED
# Elapsed time: 3.9345 seconds
# [3930, 2693, 2636, 2617, 2617, 2682, 2848, 2848] [3221, 2498, 2595, 2531, 2890, 2655, 2890, 3148]
# R2: -0.32481120463089264
# MSLE: 0.00834292436089073
# Max error: 709
# MAPE: 7.030291731898397
# MOW KZN
# Elapsed time: 6.0650 seconds
# [5349, 4556, 4366, 4359, 4293, 4282, 4444, 4483] [4498, 4172, 4248, 4226, 4172, 4172, 4248, 4248]
# R2: -11.745940830760036
# MSLE: 0.005737168359761949
# Max error: 851
# MAPE: 6.216445506304873
# MOW CEK
# Elapsed time: 3.1468 seconds
# [6591, 6146, 6174, 6151, 6388, 5975, 6490, 6212] [5460, 4998, 4998, 5777, 6148, 6148, 5635, 5817]
# R2: -2.58624915757484
# MSLE: 0.01915975915956455
# Max error: 1176
# MAPE: 12.79599160761019
# MOW SVX
# Elapsed time: 3.6844 seconds
# [5714, 4341, 4361, 4287, 4282, 4095, 4280, 4279] [4058, 3658, 3953, 3658, 3658, 3658, 3658, 4058]
# R2: -17.615820238919877
# MSLE: 0.030769018373809326
# Max error: 1656
# MAPE: 17.306366145876105
# MOW AER
# Elapsed time: 3.1762 seconds
# [6354, 5891, 6062, 6003, 5763, 6042, 6221, 6059] [3955, 4123, 5190, 5190, 5586, 5359, 6201, 6163]
# R2: -1.2475476722300844
# MSLE: 0.05161365296455801
# Max error: 2399
# MAPE: 19.241080438449778
# MOW KRR
# Elapsed time: 3.8800 seconds
# [6842, 6190, 5656, 5501, 5620, 5321, 5664, 5577] [4998, 4998, 5320, 4998, 4869, 4365, 5363, 5363]
# R2: -7.754007167757576
# MSLE: 0.02769368237462798
# Max error: 1844
# MAPE: 15.50656848535302
# MOW KGD
# Elapsed time: 4.7465 seconds
# [6449, 6332, 5954, 6418, 6845, 6136, 7278, 6151] [4820, 5920, 6428, 6428, 6428, 7000, 5618, 6876]
# R2: -1.0286959004917016
# MSLE: 0.02447997092443397
# Max error: 1660
# MAPE: 13.400950160801973
# LED MOW
# Elapsed time: 6.3862 seconds
# [3366, 2815, 2622, 2629, 2636, 2653, 2701, 2767] [3058, 2890, 2890, 2890, 2890, 2890, 2890, 2890]
# R2: -15.681608357628765
# MSLE: 0.006318173782922575
# Max error: 308
# MAPE: 7.344632944163701
# LED KZN
# Elapsed time: 4.4979 seconds
# [5780, 5773, 5731, 5166, 5778, 5782, 5818, 5822] [6823, 6845, 7070, 7582, 7724, 7362, 7362, 7888]
# R2: -19.88163304926584
# MSLE: 0.06723975818906672
# Max error: 2416
# MAPE: 21.94646560894044
# LED CEK
# Elapsed time: 4.2398 seconds
# [13212, 4196, 4138, 3840, 3840, 3998, 4317, 3998] [6736, 6668, 6629, 6880, 7257, 7996, 7060, 6510]
# R2: -63.6087522938264
# MSLE: 0.3243506237704508
# Max error: 6476
# MAPE: 48.68764245592311
# LED SVX
# Elapsed time: 2.8912 seconds
# [7056, 6071, 6040, 6138, 6079, 5918, 6247, 6197] [7126, 6802, 7563, 6190, 6190, 7563, 6190, 7988]
# R2: -1.4319877697499392
# MSLE: 0.02357800986327177
# Max error: 1791
# MAPE: 9.949068538550906
# LED AER
# Elapsed time: 2.8754 seconds
# [8025, 8012, 7872, 7711, 7863, 8319, 8403, 8104] [7982, 7188, 8397, 8375, 9098, 9026, 9098, 9098]
# R2: -0.4577773924912927
# MSLE: 0.008802289723151361
# Max error: 1235
# MAPE: 8.269339043256426
# LED KRR
# Elapsed time: 3.9049 seconds
# [7938, 6882, 6673, 6782, 8316, 7188, 7073, 7418] [6192, 6192, 6192, 6110, 7974, 8313, 8063, 7582]
# R2: 0.036109445691915876
# MSLE: 0.016232579916320156
# Max error: 1746
# MAPE: 11.296352760364435
# LED KGD
# Elapsed time: 4.9129 seconds
# [7381, 6147, 5761, 5731, 5799, 6294, 6087, 6366] [6808, 7265, 8735, 8753, 8443, 7316, 7316, 6803]
# R2: -5.085706228347705
# MSLE: 0.0736090850553136
# Max error: 3022
# MAPE: 20.11067019464474
# MOW SGC
# Elapsed time: 3.4212 seconds
# [9553, 8695, 8319, 8382, 7970, 7640, 7752, 7909] [7900, 8290, 8290, 8290, 7640, 7640, 7900, 8550]
# R2: -3.2945175957645594
# MSLE: 0.005839282314991276
# Max error: 1653
# MAPE: 5.119863759275974
# +----+-----------------------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------+
# |    | predictor_func                                      | origin   | destination   |   elapsed_time |    r2_score |   msle_score |   max_error |     mape |
# |----+-----------------------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------|
# |  0 | <function predict_queried_prices at 0x7f6912542290> | MOW      | LED           |        3.93446 |  -0.324811  |   0.00834292 |         709 |  7.03029 |
# |  1 | <function predict_queried_prices at 0x7f6912542290> | MOW      | KZN           |        6.06501 | -11.7459    |   0.00573717 |         851 |  6.21645 |
# |  2 | <function predict_queried_prices at 0x7f6912542290> | MOW      | CEK           |        3.14681 |  -2.58625   |   0.0191598  |        1176 | 12.796   |
# |  3 | <function predict_queried_prices at 0x7f6912542290> | MOW      | SVX           |        3.6844  | -17.6158    |   0.030769   |        1656 | 17.3064  |
# |  4 | <function predict_queried_prices at 0x7f6912542290> | MOW      | AER           |        3.17617 |  -1.24755   |   0.0516137  |        2399 | 19.2411  |
# |  5 | <function predict_queried_prices at 0x7f6912542290> | MOW      | KRR           |        3.88002 |  -7.75401   |   0.0276937  |        1844 | 15.5066  |
# |  6 | <function predict_queried_prices at 0x7f6912542290> | MOW      | KGD           |        4.74653 |  -1.0287    |   0.02448    |        1660 | 13.401   |
# |  7 | <function predict_queried_prices at 0x7f6912542290> | LED      | MOW           |        6.38617 | -15.6816    |   0.00631817 |         308 |  7.34463 |
# |  8 | <function predict_queried_prices at 0x7f6912542290> | LED      | KZN           |        4.49792 | -19.8816    |   0.0672398  |        2416 | 21.9465  |
# |  9 | <function predict_queried_prices at 0x7f6912542290> | LED      | CEK           |        4.23984 | -63.6088    |   0.324351   |        6476 | 48.6876  |
# | 10 | <function predict_queried_prices at 0x7f6912542290> | LED      | SVX           |        2.8912  |  -1.43199   |   0.023578   |        1791 |  9.94907 |
# | 11 | <function predict_queried_prices at 0x7f6912542290> | LED      | AER           |        2.87544 |  -0.457777  |   0.00880229 |        1235 |  8.26934 |
# | 12 | <function predict_queried_prices at 0x7f6912542290> | LED      | KRR           |        3.90492 |   0.0361094 |   0.0162326  |        1746 | 11.2964  |
# | 13 | <function predict_queried_prices at 0x7f6912542290> | LED      | KGD           |        4.91287 |  -5.08571   |   0.0736091  |        3022 | 20.1107  |
# | 14 | <function predict_queried_prices at 0x7f6912542290> | MOW      | SGC           |        3.42118 |  -3.29452   |   0.00583928 |        1653 |  5.11986 |
# +----+-----------------------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------+

# %%
! pip install sktime
# Out:
# Requirement already satisfied: sktime in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: numba>=0.50 in /usr/local/lib/python3.7/dist-packages (from sktime) (0.51.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sktime) (0.36.2)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.7/dist-packages (from sktime) (0.12.2)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from sktime) (0.24.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.7/dist-packages (from sktime) (1.19.5)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from sktime) (1.1.5)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.50->sktime) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.50->sktime) (56.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.12.1->sktime) (0.5.1)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.12.1->sktime) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->sktime) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->sktime) (2.1.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->sktime) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->sktime) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels>=0.12.1->sktime) (1.15.0)

# %%
pip install delayed
# Out:
# Collecting delayed
#   Downloading https://files.pythonhosted.org/packages/7b/80/96302b67fe8d324af597748d5eef9cfb98bb1e6590b5f25a5b58b5e6f93f/delayed-0.11.0b1-py2.py3-none-any.whl
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/33/290cea35b09c80b4634773ad5572a8030a87b5d39736719f698f521d2a13/hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85kB)
#      |████████████████████████████████| 92kB 6.1MB/s
# Collecting redis
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 6.9MB/s
# Installing collected packages: hiredis, redis, delayed
# Successfully installed delayed-0.11.0b1 hiredis-2.0.0 redis-3.5.3

# %%
from sklearn.metrics import r2_score, mean_squared_log_error, max_error

import pandas as pd
import numpy as np
import datetime
from time import perf_counter

from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon
# from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
# from sktime.forecasting.arima import ARIMA, AutoARIMA

from tabulate import tabulate

import warnings
warnings.filterwarnings('ignore')

date_parser = lambda ts: datetime.strptime(ts, "%y-%m-%dT%H:%M:%SZ")
df = pd.read_csv('aviasales_data_t.csv')
df['requested_at'] = pd.to_datetime(df['requested_at'], format="%y-%m-%dT%H:%M:%SZ", errors="coerce")
df['departure_at'] = pd.to_datetime(df['departure_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['expires_at'] = pd.to_datetime(df['expires_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['price'] = pd.to_numeric(df["price"], errors="coerce")
df = df.dropna()
df = df.drop_duplicates(subset=['departure_at', 'expires_at', 'airline', 'flight_number', 'price'], keep='first')


def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


# Profile prediction func and test prediction quality
def ml_model_test(orgn : str, dest : str,
                  current_date : datetime.datetime, flight_date : datetime.datetime,
                  predictor_f, target_f, n, m):
    # print(orgn, dest)

    tic = perf_counter()
    predictions = predictor_f(orgn, dest, current_date, flight_date, n, m)
    tac = perf_counter()
    elapsed_time = tac - tic
    
    targets = target_f(orgn, dest, current_date, flight_date)
    # print(f"Elapsed time: {elapsed_time:0.4f} seconds")
    # print(predictions[1], targets[1])
    
    r2 = r2_score(targets[1], predictions[1])
    msle = mean_squared_log_error(targets[1], predictions[1])
    max_err = max_error(targets[1], predictions[1])
    mape = mean_absolute_percentage_error(targets[1], predictions[1])
    
    # print("R2:", r2)
    # print("MSLE:", msle)
    # print("Max error:", max_err)
    # print("MAPE:", mape)
    
    return (str(predictor_f), orgn, dest, elapsed_time, r2, msle, max_err, mape)

# INSERT YOUR FUNCTION
# def predict_queried_prices(orgn, dest, current_date, flight_date):
#     days = []
#     predictions = []
#     delta = flight_date - current_date
#     for i in range(delta.days + 1):
#         days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
#         predictions.append(predict_queried_prices_for(orgn, dest, current_date, flight_date, i))
#     return days, predictions

# def predict_queried_prices_for(orgn, dest, current_date, flight_date, n_days):
    
#     orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date) 
#                    & (df["requested_at"] >= df["departure_at"] - datetime.timedelta(days=n_days + 1))
#                    & (df["requested_at"] <= df["departure_at"] - datetime.timedelta(days=n_days))] 
    
#     orgn_dest_day_min = orgn_dest.resample('D', on='requested_at')['price'].min()
  
#     orgn_dest_day_min = orgn_dest_day_min.fillna(orgn_dest_day_min.mean())  # not very smart
    
#     y = orgn_dest_day_min
#     y_train, y_test = temporal_train_test_split(y)
    
#     forecaster = AutoARIMA()
#     forecaster.fit(y_train)
#     fh = ForecastingHorizon(y_test.index, is_relative=False)
#     y_pred = forecaster.predict(fh)
#     return round(y_pred[-1])

# # INSERT YOUR FUNCTION
# def show_real_prices(orgn, dest, current_date, flight_date, delta_days=7):
    
#     orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date + datetime.timedelta(days=1))
#                    & (df["departure_at"] >= flight_date)]
    
#     days = []
#     prices = []
#     for i in range(delta_days + 1):
#         orgn_dest_day = orgn_dest[(orgn_dest["requested_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
#                            & (orgn_dest["requested_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
#         if orgn_dest_day.empty:
#             orgn_dest_day = orgn_dest[(orgn_dest["expires_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
#                                & (orgn_dest["expires_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
        
#         prices.append(round(orgn_dest_day["price"].min()))
#         days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
        
#     return days, prices

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import xgboost as xgb


def get_int(s):
    try:
        return int(s)
    except:
        return None


def init_df() -> pd.DataFrame:
    df = pd.read_csv('aviasales_data_t.csv')
    df['departure_time'] = pd.to_datetime(df['departure_at'], errors='coerce')
    df['requested_time'] = pd.to_datetime('20' + df['requested_at'], errors='coerce')
    df['before_flight'] = (df['departure_time'] - df['requested_time']).apply(
        lambda x: x.total_seconds() / 3600)
    df['requested_date'] = df['requested_time'].apply(lambda x: x.date())
    df['departure_date'] = df['departure_time'].apply(lambda x: x.date())
    df = pd.DataFrame(df[['price', 'before_flight', 'origin', 'destination', 'departure_date', 'requested_date']])
    df['price'] = df['price'].apply(lambda x: get_int(x))
    df = df.groupby(['departure_date', 'requested_date', 'origin', 'destination']).min()

    df = df.reset_index()

    return df


data = init_df()


def prepare_df(origin, destination) -> pd.DataFrame:
    df = data.loc[data['origin'] == origin]
    df = df.loc[df['destination'] == destination]
    df.drop(['origin', 'destination'], axis=1)

    return df


def create_only_date_train_features(df):
    rows = [create_date_features(df.iloc[i]) for i in range(len(df))]
    curr_df = pd.DataFrame(rows)
    return curr_df


def create_date_features(old_row):
    row = {}
    req_date = pd.to_datetime(old_row['requested_date'])
    row['req_dayofweek'] = req_date.dayofweek
    row['req_quarter'] = req_date.quarter
    row['req_month'] = req_date.month
    row['req_year'] = req_date.year
    row['req_dayofyear'] = req_date.dayofyear
    row['req_dayofmonth'] = req_date.day
    row['req_weekofyear'] = req_date.weekofyear

    dep_date = pd.to_datetime(old_row['departure_date'])
    row['dep_dayofweek'] = dep_date.dayofweek
    row['dep_quarter'] = dep_date.quarter
    row['dep_month'] = dep_date.month
    row['dep_year'] = dep_date.year
    row['dep_dayofyear'] = dep_date.dayofyear
    row['dep_dayofmonth'] = dep_date.day
    row['dep_weekofyear'] = dep_date.weekofyear

    row['before_flight'] = old_row['before_flight']
    return row


def predict(origin, destination, current_date, flight_date, n, m):
    df = prepare_df(origin, destination)
    df = df[df['departure_date'] < flight_date.date()]
    y_train = df['price']
    X_train = create_only_date_train_features(df)
    model = xgb.XGBRegressor(n_estimators=n, max_depth=m).fit(X_train, y_train)

    rows = []
    days = []
    delta = flight_date - current_date
    for i in range(delta.days + 1):
        req_date = (flight_date - timedelta(days=i)).date()
        fl_date = flight_date.date()
        before_flight = timedelta(days=i).total_seconds() / 3600
        days.append(str(req_date))
        rows.append({'departure_date': fl_date, 'requested_date': req_date, 'before_flight': before_flight})

    X_test = create_only_date_train_features(pd.DataFrame(rows))
    y_pred = model.predict(X_test)
    return days, list(y_pred)


def show_real_prices(origin, destination, current_date, flight_date, delta_days=7):
    df = prepare_df(origin, destination)
    days = []
    prices = []
    for i in range(delta_days + 1):
        req_date = (flight_date - timedelta(days=i)).date()
        fl_date = flight_date.date()
        days.append(str(req_date))
        price = None
        try:
            cur_df = df.loc[df['departure_date'] == fl_date]
            price = cur_df.loc[cur_df['requested_date'] == req_date]['price'].iloc[0]
        except:
            pass
        prices.append(price)

    return days, list(prices)


# JUST AN EXAMPLE

i = "MOW"
ml_test_results = []
for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
    for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
        if i != j:
            ml_test_results.append(ml_model_test(i, j, datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 50, 5))
           
            
ml_test_df = pd.DataFrame(ml_test_results)
ml_test_df.columns = ['predictor_func', 'origin', 'destination', 'elapsed_time', 'r2_score', 'msle_score', 'max_error', 'mape']
ml_test_df = ml_test_df[['origin', 'destination', 'elapsed_time', 'r2_score', 'max_error', 'mape']]
print(tabulate(ml_test_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# [00:29:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:29:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# +----+----------+---------------+----------------+------------+-------------+----------+
# |    | origin   | destination   |   elapsed_time |   r2_score |   max_error |     mape |
# |----+----------+---------------+----------------+------------+-------------+----------|
# |  0 | MOW      | LED           |       0.420765 |  -3.49966  |     469.758 |  9.03903 |
# |  1 | MOW      | KZN           |       0.434929 | -18.5639   |     198.997 |  3.12496 |
# |  2 | MOW      | CEK           |       0.428032 |   0.767078 |     355.85  |  2.20352 |
# |  3 | MOW      | SVX           |       0.432699 |   0.173918 |     315.75  |  3.25421 |
# |  4 | MOW      | AER           |       0.426733 |   0.62829  |     668.966 |  7.0783  |
# |  5 | MOW      | KRR           |       0.17935  |   0.159601 |     561.754 |  4.47024 |
# |  6 | MOW      | KGD           |       0.178671 |  -0.573825 |    1354.68  |  7.46899 |
# |  7 | LED      | MOW           |       0.430512 |   0        |     126.498 |  2.75519 |
# |  8 | LED      | KZN           |       0.433914 |  -0.860815 |     712.749 |  5.67876 |
# |  9 | LED      | CEK           |       0.42232  |  -0.341158 |     269.106 |  1.75687 |
# | 10 | LED      | SVX           |       0.442567 |  -0.353835 |    1257.81  |  5.63147 |
# | 11 | LED      | AER           |       0.445169 |  -1.31393  |    1311.64  |  9.48621 |
# | 12 | LED      | KRR           |       0.177255 |  -1.09753  |    2029.54  | 11.7457  |
# | 13 | LED      | KGD           |       0.177367 |  -1.24576  |    1977.95  | 13.3895  |
# +----+----------+---------------+----------------+------------+-------------+----------+

# %%
import pandas as pd
import numpy as np
import datetime


def get_int(s):
    try:
        return int(s)
    except:
        return None

def init_df() -> pd.DataFrame:
    df = pd.read_csv('aviasales_data_t.csv')
    df['departure_time'] = pd.to_datetime(df['departure_at'], errors='coerce')
    df['requested_time'] = pd.to_datetime('20' + df['requested_at'], errors='coerce')
    df['before_flight'] = (df['departure_time'] - df['requested_time']).apply(
        lambda x: x.total_seconds() / 3600)
    df['requested_date'] = df['requested_time'].apply(lambda x: x.date())
    df['departure_date'] = df['departure_time'].apply(lambda x: x.date())
    df = pd.DataFrame(df[['price', 'before_flight', 'origin', 'destination', 'departure_date', 'requested_date']])
    df['price'] = df['price'].apply(lambda x: get_int(x))
    df = df.groupby(['departure_date', 'requested_date', 'origin', 'destination']).min()
    df['before_flight'] = np.floor(df['before_flight'])
    df = df.reset_index()

    return df


data = init_df()


def prepare_df(origin, destination) -> pd.DataFrame:
    df = data.loc[data['origin'] == origin]
    df = df.loc[df['destination'] == destination]
    df.drop(['origin', 'destination'], axis=1)

    return df

df= prepare_df('MOW', 'LED')   
d = df.iloc[0]

# %%
def create_date_features(old_row):
    row = {}
    req_date = pd.to_datetime(old_row['requested_date'])
    row['req_dayofweek'] = req_date.dayofweek
    row['req_quarter'] = req_date.quarter
    row['req_month'] = req_date.month
    row['req_year'] = req_date.year
    row['req_dayofyear'] = req_date.dayofyear
    row['req_dayofmonth'] = req_date.day
    row['req_weekofyear'] = req_date.weekofyear

    dep_date = pd.to_datetime(old_row['departure_date'])
    row['dep_dayofweek'] = dep_date.dayofweek
    row['dep_quarter'] = dep_date.quarter
    row['dep_month'] = dep_date.month
    row['dep_year'] = dep_date.year
    row['dep_dayofyear'] = dep_date.dayofyear
    row['dep_dayofmonth'] = dep_date.day
    row['dep_weekofyear'] = dep_date.weekofyear

    row['before_flight'] = old_row['before_flight']
    return row

# %%
d = create_date_features(df.iloc[0])

# %%
d
# Out:
# departure_date    2021-03-06
# requested_date    2021-03-06
# origin                   MOW
# destination              LED
# price                   3568
# before_flight              1
# Name: 23, dtype: object

# %%
# d = {key: [value] for key, value in d.items()}
pd.DataFrame.from_dict(dict(d), orient='index')
# Out:
#                          0
# departure_date  2021-03-06
# requested_date  2021-03-06
# origin                 MOW
# destination            LED
# price                 3568
# before_flight            1

# %%
from sklearn.metrics import r2_score, mean_squared_log_error, max_error

import pandas as pd
import numpy as np
import datetime
from time import perf_counter

from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.base import ForecastingHorizon
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
# from sktime.forecasting.arima import ARIMA, AutoARIMA

from tabulate import tabulate

import warnings
warnings.filterwarnings('ignore')

date_parser = lambda ts: datetime.strptime(ts, "%y-%m-%dT%H:%M:%SZ")
df = pd.read_csv('direct_flights.csv')
df['requested_at'] = pd.to_datetime(df['requested_at'], format="%y-%m-%dT%H:%M:%SZ", errors="coerce")
df['departure_at'] = pd.to_datetime(df['departure_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['expires_at'] = pd.to_datetime(df['expires_at'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce")
df['price'] = pd.to_numeric(df["price"], errors="coerce")
df = df.dropna()
df = df.drop_duplicates(subset=['departure_at', 'expires_at', 'airline', 'flight_number', 'price'], keep='first')


def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


# Profile prediction func and test prediction quality
def ml_model_test(orgn : str, dest : str,
                  current_date : datetime.datetime, flight_date : datetime.datetime,
                  predictor_f, target_f, n, m):
    # print(orgn, dest)

    tic = perf_counter()
    predictions = predictor_f(orgn, dest, current_date, flight_date, n, m)
    tac = perf_counter()
    elapsed_time = tac - tic
    
    targets = target_f(orgn, dest, current_date, flight_date)
    # print(f"Elapsed time: {elapsed_time:0.4f} seconds")
    # print(predictions[1], targets[1])
    # print(predictions[1], target[1])
    r2 = r2_score(targets[1], predictions[1])
    msle = mean_squared_log_error(targets[1], predictions[1])
    max_err = max_error(targets[1], predictions[1])
    mape = mean_absolute_percentage_error(targets[1], predictions[1])
    
    # print("R2:", r2)
    # print("MSLE:", msle)
    # print("Max error:", max_err)
    # print("MAPE:", mape)
    
    return (str(predictor_f), orgn, dest, elapsed_time, r2, msle, max_err, mape)

# INSERT YOUR FUNCTION
# def predict_queried_prices(orgn, dest, current_date, flight_date):
#     days = []
#     predictions = []
#     delta = flight_date - current_date
#     for i in range(delta.days + 1):
#         days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
#         predictions.append(predict_queried_prices_for(orgn, dest, current_date, flight_date, i))
#     return days, predictions

# def predict_queried_prices_for(orgn, dest, current_date, flight_date, n_days):
    
#     orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date) 
#                    & (df["requested_at"] >= df["departure_at"] - datetime.timedelta(days=n_days + 1))
#                    & (df["requested_at"] <= df["departure_at"] - datetime.timedelta(days=n_days))] 
    
#     orgn_dest_day_min = orgn_dest.resample('D', on='requested_at')['price'].min()
  
#     orgn_dest_day_min = orgn_dest_day_min.fillna(orgn_dest_day_min.mean())  # not very smart
    
#     y = orgn_dest_day_min
#     y_train, y_test = temporal_train_test_split(y)
    
#     forecaster = AutoARIMA()
#     forecaster.fit(y_train)
#     fh = ForecastingHorizon(y_test.index, is_relative=False)
#     y_pred = forecaster.predict(fh)
#     return round(y_pred[-1])

# # INSERT YOUR FUNCTION
# def show_real_prices(orgn, dest, current_date, flight_date, delta_days=7):
    
#     orgn_dest = df[(df["origin"] == orgn) & (df["destination"] == dest) & (df["departure_at"] <= flight_date + datetime.timedelta(days=1))
#                    & (df["departure_at"] >= flight_date)]
    
#     days = []
#     prices = []
#     for i in range(delta_days + 1):
#         orgn_dest_day = orgn_dest[(orgn_dest["requested_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
#                            & (orgn_dest["requested_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
#         if orgn_dest_day.empty:
#             orgn_dest_day = orgn_dest[(orgn_dest["expires_at"] >= orgn_dest["departure_at"] - datetime.timedelta(days=i + 1))
#                                & (orgn_dest["expires_at"] <= orgn_dest["departure_at"] - datetime.timedelta(days=i))]
        
#         prices.append(round(orgn_dest_day["price"].min()))
#         days.append((flight_date - datetime.timedelta(days=i)).strftime("%Y-%m-%d"))
        
#     return days, prices

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import xgboost as xgb


def get_int(s):
    try:
        return int(s)
    except:
        return None


def init_df(name = 'direct_flights.csv') -> pd.DataFrame:
    df = pd.read_csv(name)
    if name == 'direct_flights.csv':
      df = df[df['direct'] == True]
    df['departure_time'] = pd.to_datetime(df['departure_at'], errors='coerce')
    df['requested_time'] = pd.to_datetime('20' + df['requested_at'], errors='coerce')
    df['before_flight'] = (df['departure_time'] - df['requested_time']).apply(
        lambda x: x.total_seconds() / 3600)
    df['requested_date'] = df['requested_time'].apply(lambda x: x.date())
    df['departure_date'] = df['departure_time'].apply(lambda x: x.date())
    df = pd.DataFrame(df[['price', 'before_flight', 'origin', 'destination', 'departure_date', 'requested_date']])
    df['price'] = df['price'].apply(lambda x: get_int(x))
    df = df.groupby(['departure_date', 'requested_date', 'origin', 'destination']).min()

    df = df.reset_index()

    return df

data_t = init_df()
data_r = init_df('aviasales_data_t.csv')



def prepare_df(data, origin, destination) -> pd.DataFrame:
    df = data.loc[data['origin'] == origin]
    df = df.loc[df['destination'] == destination]
    df.drop(['origin', 'destination'], axis=1)

    return df


def create_only_date_train_features(df):
    rows = [create_date_features(df.iloc[i]) for i in range(len(df))]
    curr_df = pd.DataFrame(rows)
    return curr_df


def create_date_features(old_row):
    row = {}
    req_date = pd.to_datetime(old_row['requested_date'])
    row['req_dayofweek'] = req_date.dayofweek
    row['req_quarter'] = req_date.quarter
    row['req_month'] = req_date.month
    row['req_year'] = req_date.year
    row['req_dayofyear'] = req_date.dayofyear
    row['req_dayofmonth'] = req_date.day
    row['req_weekofyear'] = req_date.weekofyear

    dep_date = pd.to_datetime(old_row['departure_date'])
    row['dep_dayofweek'] = dep_date.dayofweek
    row['dep_quarter'] = dep_date.quarter
    row['dep_month'] = dep_date.month
    row['dep_year'] = dep_date.year
    row['dep_dayofyear'] = dep_date.dayofyear
    row['dep_dayofmonth'] = dep_date.day
    row['dep_weekofyear'] = dep_date.weekofyear

    row['before_flight'] = old_row['before_flight']
    return row


def predict(origin, destination, current_date, flight_date, n, m):
    df = prepare_df(data_t, origin, destination)
    df = df[df['departure_date'] < flight_date.date()]
    y_train = df['price']
    X_train = create_only_date_train_features(df)
    model = xgb.XGBRegressor(n_estimators=n, max_depth=m).fit(X_train, y_train)

    rows = []
    days = []
    delta = flight_date - current_date
    for i in range(delta.days + 1):
        req_date = (flight_date - timedelta(days=i)).date()
        fl_date = flight_date.date()
        before_flight = timedelta(days=i).total_seconds() / 3600
        days.append(str(req_date))
        rows.append({'departure_date': fl_date, 'requested_date': req_date, 'before_flight': before_flight})

    X_test = create_only_date_train_features(pd.DataFrame(rows))
    y_pred = model.predict(X_test)
    return days, list(y_pred)


def show_real_prices(origin, destination, current_date, flight_date, delta_days=7):
    df = prepare_df(data_r, origin, destination)
    days = []
    prices = []
    for i in range(delta_days + 1):
        req_date = (flight_date - timedelta(days=i)).date()
        fl_date = flight_date.date()
        days.append(str(req_date))
        price = None
        try:
            cur_df = df.loc[df['departure_date'] == fl_date]
            price = cur_df.loc[cur_df['requested_date'] == req_date]['price'].iloc[0]
        except:
            pass
        prices.append(price)

    return days, list(prices)


# JUST AN EXAMPLE

i = "MOW"
ml_test_results = []
for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
    for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
        if i != j:
            ml_test_results.append(ml_model_test(i, j, datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 50, 5))
ml_test_results.append(ml_model_test("MOW", "SGC", datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 50, 5))            
            
ml_test_df = pd.DataFrame(ml_test_results)
ml_test_df.columns = ['predictor_func', 'origin', 'destination', 'elapsed_time', 'r2_score', 'msle_score', 'max_error', 'mape']
print(tabulate(ml_test_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# [14:12:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:12:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# +----+--------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------+
# |    | predictor_func                       | origin   | destination   |   elapsed_time |    r2_score |   msle_score |   max_error |     mape |
# |----+--------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------|
# |  0 | <function predict at 0x7f433b2ff9e0> | MOW      | LED           |      0.49594   |  -8.96319   |  0.0189236   |     717.645 | 12.8917  |
# |  1 | <function predict at 0x7f433b2ff9e0> | MOW      | KZN           |      0.516222  | -14.5795    |  0.000947235 |     169.884 |  2.81453 |
# |  2 | <function predict at 0x7f433b2ff9e0> | MOW      | CEK           |      0.442693  |  -3.44889   |  0.0150517   |    1315.88  |  8.72395 |
# |  3 | <function predict at 0x7f433b2ff9e0> | MOW      | SVX           |      0.373217  |   0.0168904 |  0.00181832  |     244.157 |  3.58571 |
# |  4 | <function predict at 0x7f433b2ff9e0> | MOW      | AER           |      0.466963  |  -2.42206   |  0.0467125   |    2429.02  | 19.9509  |
# |  5 | <function predict at 0x7f433b2ff9e0> | MOW      | KRR           |      0.18887   |  -0.420922  |  0.00518392  |     774.122 |  5.47078 |
# |  6 | <function predict at 0x7f433b2ff9e0> | MOW      | KGD           |      0.194907  |  -0.0195378 |  0.00751072  |     808.133 |  6.38579 |
# |  7 | <function predict at 0x7f433b2ff9e0> | LED      | MOW           |      0.521698  |   0         |  0.0035953   |     245.74  |  5.92115 |
# |  8 | <function predict at 0x7f433b2ff9e0> | LED      | KZN           |      0.332593  |  -3.60291   |  0.00989067  |    1053.01  |  9.5106  |
# |  9 | <function predict at 0x7f433b2ff9e0> | LED      | CEK           |      0.485152  |  -2.3488    |  0.00121507  |     331.175 |  3.04034 |
# | 10 | <function predict at 0x7f433b2ff9e0> | LED      | SVX           |      0.274919  |  -9.52942   |  0.0468991   |    1870.76  | 23.2432  |
# | 11 | <function predict at 0x7f433b2ff9e0> | LED      | AER           |      0.236969  |  -0.28883   |  0.00850669  |    1504.84  |  6.32251 |
# | 12 | <function predict at 0x7f433b2ff9e0> | LED      | KRR           |      0.0348808 |  -0.999513  |  0.0309063   |    1767.65  | 15.0632  |
# | 13 | <function predict at 0x7f433b2ff9e0> | LED      | KGD           |      0.182595  |  -0.977969  |  0.0222575   |    2530.62  | 13.3389  |
# | 14 | <function predict at 0x7f433b2ff9e0> | MOW      | SGC           |      0.193916  |  -2.12413   |  0.00199082  |     808.705 |  3.66308 |
# +----+--------------------------------------+----------+---------------+----------------+-------------+--------------+-------------+----------+

# %%
! pip install delayed
# Out:
# Collecting delayed
#   Downloading https://files.pythonhosted.org/packages/7b/80/96302b67fe8d324af597748d5eef9cfb98bb1e6590b5f25a5b58b5e6f93f/delayed-0.11.0b1-py2.py3-none-any.whl
# Collecting redis
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 4.8MB/s
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/33/290cea35b09c80b4634773ad5572a8030a87b5d39736719f698f521d2a13/hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85kB)
#      |████████████████████████████████| 92kB 6.0MB/s
# Installing collected packages: redis, hiredis, delayed
# Successfully installed delayed-0.11.0b1 hiredis-2.0.0 redis-3.5.3

# %%
! pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/f4/c2/2a94bce6bba1deac3c0b16dbb14f28de0b9035e3211919cae8448455aa65/pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 4.0MB/s
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (56.0.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.24.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.22)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels!=0.12.0,>=0.11->pmdarima) (1.15.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.8.2

# %%
from tqdm.notebook import tqdm

n_estimators = [50, 100, 150, 200, 300, 400, 500]
max_depth = [5, 10, 15, 20, 30, 40, 50]

best_n = 0
best_m = 0
best_mape = np.inf

for n in tqdm(n_estimators):
  for m in max_depth:
    cur_mape = 0
    for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
        for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
            if i != j:
                _, mape = ml_model_test(i, j, datetime(2021,4,20), datetime(2021,4,27),
                                                predict, show_real_prices, n, m)
                cur_mape += mape
    if best_mape > cur_mape:
       best_mape = cur_mape
       best_n = n
       best_m = m
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# [02:25:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:25:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:27:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:28:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:29:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [02:34:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:36:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:37:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:38:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print(best_n, best_m)
# Out:
# 50 10

# %%
i = "MOW"
ml_test_results = []
for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
    for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
        if i != j:
            ml_test_results.append(ml_model_test(i, j, datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 50, 10))
ml_test_results.append(ml_model_test("MOW", "SGC", datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 50, 10))            
            
ml_test_df = pd.DataFrame(ml_test_results)
ml_test_df.columns = ['predictor_func', 'origin', 'destination', 'elapsed_time', 'r2_score', 'msle_score', 'max_error', 'mape']
print(tabulate(ml_test_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# [02:40:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:40:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# +----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------+
# |    | predictor_func                       | origin   | destination   |   elapsed_time |   r2_score |   msle_score |   max_error |     mape |
# |----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------|
# |  0 | <function predict at 0x7f4a60a674d0> | MOW      | LED           |       0.555244 |  -1.38772  |  0.00487748  |     332.926 |  6.19832 |
# |  1 | <function predict at 0x7f4a60a674d0> | MOW      | KZN           |       0.52695  |  -5.03453  |  0.000368194 |     160.021 |  1.64118 |
# |  2 | <function predict at 0x7f4a60a674d0> | MOW      | CEK           |       0.544231 |   0.73577  |  0.000884335 |     365.784 |  2.30079 |
# |  3 | <function predict at 0x7f4a60a674d0> | MOW      | SVX           |       0.546767 |   0.29796  |  0.00128515  |     368.996 |  2.06173 |
# |  4 | <function predict at 0x7f4a60a674d0> | MOW      | AER           |       0.572541 |   0.521279 |  0.00758033  |     622.832 |  8.3596  |
# |  5 | <function predict at 0x7f4a60a674d0> | MOW      | KRR           |       0.220395 |   0.268218 |  0.00290323  |     512.24  |  4.21521 |
# |  6 | <function predict at 0x7f4a60a674d0> | MOW      | KGD           |       0.21965  |  -0.882658 |  0.0145063   |    1560.88  |  7.49692 |
# |  7 | <function predict at 0x7f4a60a674d0> | LED      | MOW           |       0.535295 |   0        |  0.000659559 |     171.99  |  1.57109 |
# |  8 | <function predict at 0x7f4a60a674d0> | LED      | KZN           |       0.547624 |  -0.435788 |  0.00315502  |     585.215 |  5.16889 |
# |  9 | <function predict at 0x7f4a60a674d0> | LED      | CEK           |       0.558169 |  -1.76267  |  0.000998267 |     405.71  |  2.52739 |
# | 10 | <function predict at 0x7f4a60a674d0> | LED      | SVX           |       0.536686 |  -1.42738  |  0.0117553   |    1457.67  |  7.21987 |
# | 11 | <function predict at 0x7f4a60a674d0> | LED      | AER           |       0.548974 |  -0.236441 |  0.00653891  |    1023.95  |  7.04919 |
# | 12 | <function predict at 0x7f4a60a674d0> | LED      | KRR           |       0.224223 |  -1.34959  |  0.0372537   |    2030.47  | 13.1026  |
# | 13 | <function predict at 0x7f4a60a674d0> | LED      | KGD           |       0.224843 |  -1.39735  |  0.030225    |    1918.56  | 14.4467  |
# | 14 | <function predict at 0x7f4a60a674d0> | MOW      | SGC           |       0.228747 |  -2.53793  |  0.00217718  |     953.42  |  3.44607 |
# +----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------+

# %%
i = "MOW"
ml_test_results = []
for i in ['MOW', 'LED']: # NaNs in others , 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD'
    for j in ['MOW', 'LED', 'KZN', 'CEK', 'SVX', 'AER', 'KRR', 'KGD']: # , 'SGC'
        if i != j:
            ml_test_results.append(ml_model_test(i, j, datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 200, 20))
ml_test_results.append(ml_model_test("MOW", "SGC", datetime(2021,4,20), datetime(2021,4,27),
                                             predict, show_real_prices, 200, 20))            
            
ml_test_df = pd.DataFrame(ml_test_results)
ml_test_df.columns = ['predictor_func', 'origin', 'destination', 'elapsed_time', 'r2_score', 'msle_score', 'max_error', 'mape']
print(tabulate(ml_test_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# [02:41:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:41:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:42:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:42:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:42:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:42:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:42:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# +----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------+
# |    | predictor_func                       | origin   | destination   |   elapsed_time |   r2_score |   msle_score |   max_error |     mape |
# |----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------|
# |  0 | <function predict at 0x7f4a60a674d0> | MOW      | LED           |       1.3692   | -3.85998   |  0.00977772  |     457.888 |  9.1585  |
# |  1 | <function predict at 0x7f4a60a674d0> | MOW      | KZN           |       1.36567  | -3.89124   |  0.000293602 |     120.313 |  1.44424 |
# |  2 | <function predict at 0x7f4a60a674d0> | MOW      | CEK           |       1.41467  |  0.613156  |  0.00133293  |     396.95  |  2.45074 |
# |  3 | <function predict at 0x7f4a60a674d0> | MOW      | SVX           |       1.38082  |  0.254743  |  0.00136173  |     381.085 |  1.86143 |
# |  4 | <function predict at 0x7f4a60a674d0> | MOW      | AER           |       1.40688  |  0.428331  |  0.00901152  |     706.753 |  8.52269 |
# |  5 | <function predict at 0x7f4a60a674d0> | MOW      | KRR           |       0.538038 |  0.191119  |  0.00320829  |     485.041 |  4.67163 |
# |  6 | <function predict at 0x7f4a60a674d0> | MOW      | KGD           |       0.547712 | -0.79282   |  0.0137672   |    1528.59  |  7.44088 |
# |  7 | <function predict at 0x7f4a60a674d0> | LED      | MOW           |       1.34429  |  0         |  0.000710855 |     113.603 |  2.28054 |
# |  8 | <function predict at 0x7f4a60a674d0> | LED      | KZN           |       1.38055  | -0.859352  |  0.00406691  |     639.939 |  5.85118 |
# |  9 | <function predict at 0x7f4a60a674d0> | LED      | CEK           |       1.42441  | -3.78186   |  0.00170417  |     549.494 |  3.21139 |
# | 10 | <function predict at 0x7f4a60a674d0> | LED      | SVX           |       1.37229  | -1.36607   |  0.0111525   |    1445.21  |  5.83915 |
# | 11 | <function predict at 0x7f4a60a674d0> | LED      | AER           |       1.3608   | -0.0302449 |  0.00552434  |     857.048 |  6.551   |
# | 12 | <function predict at 0x7f4a60a674d0> | LED      | KRR           |       0.54057  | -1.35073   |  0.0373455   |    2087.43  | 13.5938  |
# | 13 | <function predict at 0x7f4a60a674d0> | LED      | KGD           |       0.526687 | -1.31658   |  0.0292804   |    1870.19  | 14.4564  |
# | 14 | <function predict at 0x7f4a60a674d0> | MOW      | SGC           |       0.55541  | -5.96054   |  0.00411479  |    1313.98  |  4.9663  |
# +----+--------------------------------------+----------+---------------+----------------+------------+--------------+-------------+----------+
